# %% [markdown]
# <p style="text-align:center; font-size:20px;">
# <b> Retail Sales Data Analysis</b><br><br>
# <b>Internship Project – Oasis Infobyte</b><br><br>
# 👤 <b>Name:</b> Ahmer Mehmood <br>
# 🎓 <b>Role:</b> Data Analyst Intern <br>
# 📅 <b>Batch:</b> September 2025
# </p>

# %%
import numpy as np

import  pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('retail_sales_dataset.csv')

# %%
df.shape
# Out:
# (1000, 9)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
print(df.isnull().sum())
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# STANDERD DEVIATION  

# 1 MEAN

print("Mean:", df['Total Amount'].mean()) # average  mean = sym of all /numbr of values  

print("Median:",df['Total Amount'].median()) # miffle vlaue  if  odd  then single one  if even then add 2  middle by arrange first  then divede  into it

print("Mode:", df['Total Amount'].mode()[0]) # most time occur 
print("Mode:", df['Total Amount'].mode()) # so to ge tthe diffenrce between  these two i got th  point 
print("std",df['Total Amount'].std())
# Out:
# Mean: 456.0
# Median: 135.0
# Mode: 50
# Mode: 0    50
# Name: Total Amount, dtype: int64
# std 559.997631555123

# %%
print("Age: ",df['Age'].mode()[0])
print("Age: ",df['Age'].mode())
# Out:
# Age:  43
# Age:  0    43
# 1    64
# Name: Age, dtype: int64

# %%
# Step 1: Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Step 2: Group by Date and sum Total Amount
daily_sales = df.groupby('Date')['Total Amount'].sum()

# Step 3: Show first 10 results
print(daily_sales.head(10))

# Step 4: Plot (we will add graphs later)
import matplotlib.pyplot as plt

daily_sales.plot(kind='line', figsize=(10,5), title="Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.show()
# Out:
# Date
# 2023-01-01    3600
# 2023-01-02    1765
# 2023-01-03     600
# 2023-01-04    1240
# 2023-01-05    1100
# 2023-01-06     620
# 2023-01-07     150
# 2023-01-08     625
# 2023-01-09     200
# 2023-01-10     230
# Name: Total Amount, dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'])

print(df['Date'].head())
print(df.info())
# Out:
# 0   2023-11-24
# 1   2023-02-27
# 2   2023-01-13
# 3   2023-05-21
# 4   2023-05-06
# Name: Date, dtype: datetime64[ns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 70.4+ KB
# None

# %%
dailysales=df.groupby('Date')['Total Amount'].sum()
print (dailysales)
# Out:
# Date
# 2023-01-01    3600
# 2023-01-02    1765
# 2023-01-03     600
# 2023-01-04    1240
# 2023-01-05    1100
#               ...
# 2023-12-27     700
# 2023-12-28    2075
# 2023-12-29    3400
# 2023-12-31      50
# 2024-01-01    1530
# Name: Total Amount, Length: 345, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(daily_sales.index, daily_sales.values, marker='o')
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.title("Daily Sales Trend")
plt.show()

# %%
#  which gende rbuys  more  :----

sales_by_gender=df.groupby('Gender')['Total Amount'].sum()

print(sales_by_gender)
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total Amount, dtype: int64

# %%
# avergae  age  of the cusotmers:-
print("Average Age ofthe customers:-",df['Age'].mean())
# Out:
# Average Age ofthe customers:- 41.392

# %%
df.head(10)
# Out:
#    Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0               1 2023-11-24     CUST001    Male   34           Beauty
# 1               2 2023-02-27     CUST002  Female   26         Clothing
# 2               3 2023-01-13     CUST003    Male   50      Electronics
# 3               4 2023-05-21     CUST004    Male   37         Clothing
# 4               5 2023-05-06     CUST005    Male   30           Beauty
# 5               6 2023-04-25     CUST006  Female   45           Beauty
# 6               7 2023-03-13     CUST007    Male   46         Clothing
# 7               8 2023-02-22     CUST008    Male   30      Electronics
# 8               9 2023-12-13     CUST009    Male   63      Electronics
# 9              10 2023-10-07     CUST010  Female   52         Clothing
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# ...

# %%
top_category = sales_by_category.idxmax()
top_revenue = sales_by_category.max()

print("Top Revenue Category:", top_category)
print("Revenue:", top_revenue)
sales_by_category.plot(kind='bar', figsize=(8,5), title="Revenue by Product Category")
plt.ylabel("Total Revenue")
plt.show()
# Out:
# Top Revenue Category: Electronics
# Revenue: 156905

# %%
quantity_by_category = df.groupby('Product Category')['Quantity'].sum()
print(quantity_by_category)
# Out:
# Product Category
# Beauty         771
# Clothing       894
# Electronics    849
# Name: Quantity, dtype: int64

# %%
sales_by_category = df.groupby('Product Category')['Total Amount'].sum()
print(sales_by_category)
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %%
top_category = sales_by_category.idxmax()
top_revenue = sales_by_category.max()
print("Top Revenue Category:", top_category)
print("Revenue:", top_revenue)
# Out:
# Top Revenue Category: Electronics
# Revenue: 156905

# %%
                                               # RECOMMENDATIONS:------

#  Focus marketing on high-performing categories (e.g., Electronics).

# Create promotional strategies for underperforming categories.

# Run weekday promotions to stabilize sales trends.

# Offer loyalty programs for top-spending customers.

# Target ads toward the dominant demographic group
